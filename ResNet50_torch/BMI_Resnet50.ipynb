# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

from PIL import Image
import os 
import glob
import random

random.seed(42)

# %%
# Restart

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from scipy.stats import boxcox

# Load the CSV file
df = pd.read_csv("data.csv")
# Set your base path where images are stored.
image_base_path = "BMI/Data/Images"  # update this to your actual image directory

# Load the CSV file
df = pd.read_csv("data.csv")

# Create a new column 'file_path' with the full path for each image.
df['file_path'] = df['name'].apply(lambda x: os.path.join(image_base_path, x))
# df['bmi_boxcox'], fitted_lambda = boxcox(df['bmi_adjusted'])
# Keep only the rows where the file exists.
df = df[df['file_path'].apply(os.path.exists)]
df['sex'] = df['gender'].map({'Male': 0, 'Female': 1})

# %%
# Split into training and test sets based on the 'is_training' flag
df_train_full = df[df['is_training'] == 1]
df_test = df[df['is_training'] == 0]

# Further split the full training set into train and validation sets 
df_train, df_valid = train_test_split(df_train_full, test_size=0.1, random_state=42)

# %%
import os



def build_img_list(df, image_base_path):
    """
    Returns a list of tuples: (full_image_path, bmi, sex)
    Assumes df contains columns: 'name', 'bmi', and 'sex'
    """
    return [
        (os.path.join(image_base_path, row['name']), row['bmi'], row['sex'])
        for _, row in df.iterrows()
    ]

train_img_lst = build_img_list(df_train, image_base_path)
valid_img_lst = build_img_list(df_valid, image_base_path)
test_img_lst  = build_img_list(df_test, image_base_path)

# %%
import torchvision.transforms as transforms

train_transforms = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(p=0.5),
    # transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomRotation(degrees=20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2023, 0.1994, 0.2010]),
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.33))
])


valid_transforms = transforms.Compose([
    transforms.Resize((256, 256)),              # Resize to 256x256
    transforms.CenterCrop((224, 224)),            # Center crop to 224x224
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2023, 0.1994, 0.2010])
])

# Try: more advanced data augmentation

# %%
import torch
from torch.utils.data import Dataset
from PIL import Image

class CustomImageDataset(Dataset):
    def __init__(self, img_list, transform=None):
        """
        img_list: List of tuples (image_path, bmi, sex)
        transform: Image transformations to apply
        """
        self.img_list = img_list  
        self.transform = transform

    def __len__(self):
        return len(self.img_list)

    def __getitem__(self, idx):
        img_path, bmi, sex = self.img_list[idx]
        # Open the image and convert to RGB
        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        
        # Convert bmi and sex to tensors (adjust types as needed)
        bmi = torch.tensor(bmi, dtype=torch.float32)
        sex = torch.tensor(sex, dtype=torch.float32)
        
        # Return the image and its corresponding features/labels.
        return image, bmi, sex

# %%
df
# Out:
#       Unnamed: 0        bmi  gender  is_training          name  \
# 0              0  34.207396    Male            1     img_0.bmp
# 1              1  26.453720    Male            1     img_1.bmp
# 2              2  34.967561  Female            1     img_2.bmp
# 3              3  22.044766  Female            1     img_3.bmp
# 6              6  25.845588  Female            1     img_6.bmp
# ...          ...        ...     ...          ...           ...
# 4201        4201  34.078947    Male            0  img_4201.bmp
# 4202        4202  34.564776  Female            0  img_4202.bmp
# 4203        4203  27.432362  Female            0  img_4203.bmp
# 4204        4204  40.492800    Male            0  img_4204.bmp
# 4205        4205  34.618844    Male            0  img_4205.bmp
#
#                          file_path  sex
# 0        BMI/Data/Images\img_0.bmp    0
# 1        BMI/Data/Images\img_1.bmp    0
# 2        BMI/Data/Images\img_2.bmp    1
# 3        BMI/Data/Images\img_3.bmp    1
# 6        BMI/Data/Images\img_6.bmp    1
# ...                            ...  ...
# 4201  BMI/Data/Images\img_4201.bmp    0
# 4202  BMI/Data/Images\img_4202.bmp    1
# 4203  BMI/Data/Images\img_4203.bmp    1
# 4204  BMI/Data/Images\img_4204.bmp    0
# 4205  BMI/Data/Images\img_4205.bmp    0
#
# [3962 rows x 7 columns]

# %%
# Create your datasets using your lists and appropriate transforms
train_data = CustomImageDataset(train_img_lst, transform=train_transforms)
valid_data = CustomImageDataset(valid_img_lst, transform=valid_transforms)
test_data = CustomImageDataset(test_img_lst, transform=valid_transforms)

# %%
batch_size = 16

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %%
for batch, (X, y, sex) in enumerate(train_loader):
    if torch.isnan(X).any():
        print(f"NaN detected in images at batch {batch}")
    if torch.isnan(y).any():
        print(f"NaN detected in BMI targets at batch {batch}")
    if torch.isnan(sex).any():
        print(f"NaN detected in sex feature at batch {batch}")

# %%
import torch
import torch.nn as nn
import torchvision

class ResNet50(nn.Module):
    def __init__(self, load_weights=True, freeze_hidden_layers=False):
        super(ResNet50, self).__init__()

        # Load the pretrained ResNet50 model.
        self.base_model = torchvision.models.resnet50(pretrained=load_weights)
        
        # Get the number of features from the original fc layer.
        num_ftrs = self.base_model.fc.in_features
        
        # Remove the original fc layer.
        self.base_model.fc = nn.Identity()
        
        # Create a new fc layer that accepts both the image features and the extra sex feature.
        # We add one extra input feature to account for sex.
        self.fc_reg = nn.Linear(num_ftrs + 1, 1)
        
        if freeze_hidden_layers:
            for name, param in self.base_model.named_parameters():
                param.requires_grad = False
            # Optionally, allow gradients for the new fc_reg layer
            for param in self.fc_reg.parameters():
                param.requires_grad = True

    def forward(self, x, sex):
        # Get features from the base model.
        features = self.base_model(x)
        # Ensure the sex feature has shape [batch_size, 1]
        if len(sex.shape) == 1:
            sex = sex.unsqueeze(1)
        # Concatenate the image features with the sex feature.
        combined = torch.cat((features, sex), dim=1)
        # Produce the final regression output.
        output = self.fc_reg(combined)
        return output

# %%
import torch
import torchvision
import torch.nn as nn

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
print(f'Device Currently Using: {torch.cuda.get_device_name(torch.cuda.current_device())}')
# Out:
# Using cuda device
# Device Currently Using: NVIDIA GeForce RTX 3060

# %%
def train(dataloader, model, loss_function, optimizer):
    # Set model to training mode.
    model.train()
    size = len(dataloader.dataset)

    for batch, (X, y, sex) in enumerate(dataloader):
        # Move inputs and labels to device
        X, y, sex = X.to(device), y.to(device), sex.to(device)

        # Forward pass: pass both image and sex feature to your model.
        pred = model(X, sex)         
        # loss = loss_function(pred, y) 
        loss = loss_function(pred.squeeze(1), y)

        optimizer.zero_grad()  
        loss.backward()        
        optimizer.step()     

        if batch % 32 == 0:
            loss_val, current = loss.item(), batch * len(X)
            print(f"loss: {loss_val:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def valid(dataloader, model, loss_function):
    model.eval()
    total_loss = 0.0
    total_abs_error = 0.0
    total_samples = 0
    total_mae_loss = 0.0
    with torch.no_grad(): 
        for X, y, sex in dataloader:
            # Move inputs and labels (and extra feature) to device.
            X, y, sex = X.to(device), y.to(device), sex.to(device)
            
            # Forward pass with the extra feature
            pred = model(X, sex)
            
            # Compute loss
            
            # loss = loss_func(pred, y)
            loss = loss_function(pred.squeeze(1), y)
            mae_loss = nn.L1Loss()(pred.squeeze(1), y)
            batch_size = X.size(0)
            total_loss += loss.item() * batch_size
            total_mae_loss += mae_loss.item() * batch_size
            # Compute absolute error for regression (MAE)
            total_abs_error += torch.abs(pred - y).sum().item()
            
            total_samples += batch_size
            


    avg_loss = total_loss / total_samples
    avg_mae_loss = total_mae_loss / total_samples
    avg_abs_error = total_abs_error / total_samples
    print(f"Validation Error: \n MSE Loss: {avg_loss:>8f} \n MAE Loss: {avg_mae_loss:>8f}\n")
    return avg_loss, avg_mae_loss

# %%
def test(dataloader, model, loss_function):
    y_true, y_pred = [], []
    total_loss = 0.0
    total_samples = 0

    model.eval()

    with torch.no_grad(): 
        for X, y, sex in dataloader:
            # Move the image, BMI label, and sex feature to the device.
            X, y, sex = X.to(device), y.to(device), sex.to(device)

            # Forward pass: pass both the image and sex feature to your model.
            pred = model(X, sex)
            
            # Accumulate predictions and true values.
            y_pred.extend(pred.view(-1).detach().cpu().numpy())
            y_true.extend(y.view(-1).detach().cpu().numpy())

            # Multiply by batch size for an accurate total loss.
            batch_size = X.size(0)
            total_loss += loss_function(pred.squeeze(1), y)* batch_size
            total_samples += batch_size

    # Calculate the average loss over all samples.
    avg_loss = total_loss / total_samples

    # Calculate a regression metric (e.g., Mean Absolute Error)
    mae = sum(abs(p - t) for p, t in zip(y_pred, y_true)) / total_samples

    print(f"Test Error:\n Avg Loss: {avg_loss:>8f}\n Avg MAE: {mae:>8f}")
    return avg_loss, mae, y_true, y_pred

# %%
optimizers = ['Adam', 'SGD']
# learning_rates = np.logspace(-6, -1, 10)
learning_rates = np.logspace(-5, -4, 10)

# learning_rates = learning_rates[3:10]
print(learning_rates)
# Out:
# [1.00000000e-05 1.29154967e-05 1.66810054e-05 2.15443469e-05
#  2.78255940e-05 3.59381366e-05 4.64158883e-05 5.99484250e-05
#  7.74263683e-05 1.00000000e-04]

# %%
grid_hist = {}

# %%
for opt in optimizers:
    grid_hist[opt] = {}
    for lr_idx, lr in enumerate(learning_rates):
        if lr_idx >= 4:
            print('Skipping lr of', learning_rates[lr_idx])
            continue

        # Create a new model instance that expects both image and sex as inputs.
        model = ResNet50().to(device)  # Ensure model.forward accepts (X, sex)
        
        grid_hist[opt][lr_idx] = {}
        grid_hist[opt][lr_idx]['minLoss'] = 0
        print('==============Training with {} at lr = {}=============='.format(opt, lr))
        
        # Choose optimizer based on option.
        if opt == 'Adam':
            optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)
        elif opt == 'SGD':
            optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=1e-5)

        # For regression (e.g., BMI prediction), use Mean Squared Error Loss.
        criterion = nn.MSELoss()  
        max_epochs = 250
        current_min_loss = np.inf
        current_best_metric = np.inf  
        current_best_pcorr = 0.0
        earlyStop_cnt = 0
        for t in range(max_epochs):
            print(f"Epoch {t+1}\n-------------------------------")
            # The train function should unpack (X, y, sex) and call model(X, sex)
            train(train_loader, model, criterion, optimizer)
            # Similarly, valid should be modified to handle the extra feature.
            eval_loss, eval_metric = valid(valid_loader, model, criterion)

            # Save the best model based on the lowest loss.
            if eval_metric < current_min_loss:
                torch.save(model.state_dict(), 'best_lr_resnet50_{}_{}.pth'.format(opt, lr_idx))
                print('Best Saved!', eval_metric)
                current_min_loss = eval_metric
                earlyStop_cnt = 0
                
                from scipy.stats import pearsonr
                def evaluate_model(model, dataloader, device):
                    """
                    Evaluate the model on a dataloader and return the ground truth and predicted BMI values.
                    Assumes each batch from the dataloader returns a tuple: (X, y, sex)
                    """
                    model.eval()
                    all_preds = []
                    all_targets = []
                    with torch.no_grad():
                        for X, y, sex in dataloader:
                            X, y, sex = X.to(device), y.to(device), sex.to(device)
                            preds = model(X, sex)
                            # Squeeze predictions from [batch_size, 1] to [batch_size]
                            preds = preds.squeeze(1)
                            all_preds.extend(preds.cpu().numpy())
                            all_targets.extend(y.cpu().numpy())
                    return np.array(all_targets), np.array(all_preds)
                y_true, y_pred = evaluate_model(model, test_loader, device)
                pearson_corr, p_value = pearsonr(y_true, y_pred)
                if pearson_corr > current_best_pcorr:
                    torch.save(model.state_dict(), 'best_corr_resnet50_{}_{}.pth'.format(opt, lr_idx))
                    current_best_pcorr = pearson_corr
                    print(f"Current Best pcorr: {current_best_pcorr}")
                    
            else:
                earlyStop_cnt += 1
            
            # For regression, lower metric (e.g., MAE) is better.
            # if eval_metric < current_best_metric:
            #     print('Best Metric:', eval_metric)
            #     current_best_metric = eval_metric

            grid_hist[opt][lr_idx]['minLoss'] = current_min_loss
            grid_hist[opt][lr_idx]['bestMetric'] = current_best_metric

            if earlyStop_cnt >= 20:
                print('Early Stopped!')
                break
            print('Current no-progress epoch:', earlyStop_cnt, '\n')
# Out:
# C:\Users\chien\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\chien\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ==============Training with Adam at lr = 1e-05==============
# Epoch 1
# -------------------------------
# loss: 968.330444  [    0/ 2889]
# loss: 1343.946533  [  512/ 2889]
# loss: 912.424316  [ 1024/ 2889]
# loss: 1080.367188  [ 1536/ 2889]
# loss: 750.888977  [ 2048/ 2889]
# loss: 875.790527  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 834.379977
#  MAE Loss: 27.685800
#
# Best Saved! 27.685800314692322
# Current Best pcorr: 0.24838215539889122
# Current no-progress epoch: 0
#
# Epoch 2
# -------------------------------
# loss: 1033.884033  [    0/ 2889]
# loss: 856.967163  [  512/ 2889]
# loss: 764.287964  [ 1024/ 2889]
# loss: 659.794800  [ 1536/ 2889]
# loss: 720.170898  [ 2048/ 2889]
# loss: 600.475220  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 703.747428
#  MAE Loss: 25.255252
#
# Best Saved! 25.2552521845262
# Current Best pcorr: 0.25226267175532735
# Current no-progress epoch: 0
#
# Epoch 3
# -------------------------------
# loss: 680.855957  [    0/ 2889]
# loss: 623.159180  [  512/ 2889]
# loss: 582.123047  [ 1024/ 2889]
# loss: 462.585419  [ 1536/ 2889]
# loss: 414.368591  [ 2048/ 2889]
# loss: 770.553650  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 579.211095
#  MAE Loss: 22.685947
#
# Best Saved! 22.685946705185366
# Current Best pcorr: 0.31969574891941765
# Current no-progress epoch: 0
#
# Epoch 4
# -------------------------------
# loss: 508.001648  [    0/ 2889]
# loss: 650.375854  [  512/ 2889]
# loss: 339.270447  [ 1024/ 2889]
# loss: 518.861450  [ 1536/ 2889]
# loss: 486.550049  [ 2048/ 2889]
# loss: 470.350494  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 491.561378
#  MAE Loss: 20.673072
#
# Best Saved! 20.673071899889415
# Current Best pcorr: 0.3246386721435871
# Current no-progress epoch: 0
#
# Epoch 5
# -------------------------------
# loss: 400.392487  [    0/ 2889]
# loss: 440.257263  [  512/ 2889]
# loss: 342.565704  [ 1024/ 2889]
# loss: 345.036560  [ 1536/ 2889]
# loss: 373.135040  [ 2048/ 2889]
# loss: 286.564880  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 417.676355
#  MAE Loss: 18.824967
#
# Best Saved! 18.82496731006468
# Current Best pcorr: 0.3444235076143961
# Current no-progress epoch: 0
#
# Epoch 6
# -------------------------------
# loss: 615.752380  [    0/ 2889]
# loss: 322.641174  [  512/ 2889]
# loss: 379.451935  [ 1024/ 2889]
# loss: 215.345245  [ 1536/ 2889]
# loss: 476.129822  [ 2048/ 2889]
# loss: 319.412781  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 349.371874
#  MAE Loss: 16.915790
#
# Best Saved! 16.915789761647257
# Current Best pcorr: 0.3505634448953581
# Current no-progress epoch: 0
#
# Epoch 7
# -------------------------------
# loss: 474.692657  [    0/ 2889]
# loss: 231.844955  [  512/ 2889]
# loss: 252.127716  [ 1024/ 2889]
# loss: 257.020294  [ 1536/ 2889]
# loss: 265.570740  [ 2048/ 2889]
# loss: 224.944122  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 287.792581
#  MAE Loss: 14.982134
#
# Best Saved! 14.982134192160729
# Current no-progress epoch: 0
#
# Epoch 8
# -------------------------------
# loss: 262.967529  [    0/ 2889]
# loss: 276.026855  [  512/ 2889]
# loss: 206.367447  [ 1024/ 2889]
# loss: 286.307251  [ 1536/ 2889]
# loss: 297.594604  [ 2048/ 2889]
# loss: 90.282089  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 231.594765
#  MAE Loss: 13.058567
#
# Best Saved! 13.058567338272047
# Current no-progress epoch: 0
#
# Epoch 9
# -------------------------------
# loss: 247.736023  [    0/ 2889]
# loss: 251.646240  [  512/ 2889]
# loss: 289.084686  [ 1024/ 2889]
# loss: 179.964935  [ 1536/ 2889]
# loss: 223.815018  [ 2048/ 2889]
# loss: 119.207283  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 210.665427
#  MAE Loss: 12.330730
#
# Best Saved! 12.330730372871566
# Current Best pcorr: 0.41340787076822866
# Current no-progress epoch: 0
#
# Epoch 10
# -------------------------------
# loss: 167.002472  [    0/ 2889]
# loss: 218.304443  [  512/ 2889]
# loss: 129.922501  [ 1024/ 2889]
# loss: 137.806793  [ 1536/ 2889]
# loss: 93.145447  [ 2048/ 2889]
# loss: 360.739136  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 187.540801
#  MAE Loss: 11.392317
#
# Best Saved! 11.392316509258709
# Current Best pcorr: 0.427998964126281
# Current no-progress epoch: 0
#
# Epoch 11
# -------------------------------
# loss: 94.374283  [    0/ 2889]
# loss: 213.452606  [  512/ 2889]
# loss: 231.812103  [ 1024/ 2889]
# loss: 179.190231  [ 1536/ 2889]
# loss: 201.212311  [ 2048/ 2889]
# loss: 179.000336  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 120.379736
#  MAE Loss: 8.509354
#
# Best Saved! 8.509353554508769
# Current no-progress epoch: 0
#
# Epoch 12
# -------------------------------
# loss: 234.239456  [    0/ 2889]
# loss: 123.818207  [  512/ 2889]
# loss: 80.848877  [ 1024/ 2889]
# loss: 154.650345  [ 1536/ 2889]
# loss: 67.943764  [ 2048/ 2889]
# loss: 105.169670  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 98.002747
#  MAE Loss: 7.315525
#
# Best Saved! 7.3155247994301105
# Current no-progress epoch: 0
#
# Epoch 13
# -------------------------------
# loss: 88.064697  [    0/ 2889]
# loss: 102.786011  [  512/ 2889]
# loss: 98.177834  [ 1024/ 2889]
# loss: 119.061081  [ 1536/ 2889]
# loss: 87.260551  [ 2048/ 2889]
# loss: 68.638199  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 94.190625
#  MAE Loss: 7.287512
#
# Best Saved! 7.287511540350513
# Current Best pcorr: 0.4492808537001219
# Current no-progress epoch: 0
#
# Epoch 14
# -------------------------------
# loss: 35.724533  [    0/ 2889]
# loss: 54.867157  [  512/ 2889]
# loss: 120.554100  [ 1024/ 2889]
# loss: 64.488838  [ 1536/ 2889]
# loss: 41.290115  [ 2048/ 2889]
# loss: 126.906517  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 83.036864
#  MAE Loss: 6.520442
#
# Best Saved! 6.520442124839141
# Current no-progress epoch: 0
#
# Epoch 15
# -------------------------------
# loss: 77.804405  [    0/ 2889]
# loss: 40.042152  [  512/ 2889]
# loss: 61.418743  [ 1024/ 2889]
# loss: 117.896835  [ 1536/ 2889]
# loss: 129.101166  [ 2048/ 2889]
# loss: 96.859467  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 94.366461
#  MAE Loss: 7.125969
#
# Current no-progress epoch: 1
#
# Epoch 16
# -------------------------------
# loss: 57.060860  [    0/ 2889]
# loss: 43.847786  [  512/ 2889]
# loss: 60.870735  [ 1024/ 2889]
# loss: 20.276491  [ 1536/ 2889]
# loss: 74.671776  [ 2048/ 2889]
# loss: 47.633736  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 60.612410
#  MAE Loss: 5.642775
#
# Best Saved! 5.642775158273097
# Current Best pcorr: 0.47306455055575825
# Current no-progress epoch: 0
#
# Epoch 17
# -------------------------------
# loss: 62.320229  [    0/ 2889]
# loss: 22.199318  [  512/ 2889]
# loss: 34.090416  [ 1024/ 2889]
# loss: 73.466782  [ 1536/ 2889]
# loss: 16.720919  [ 2048/ 2889]
# loss: 53.530323  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 59.076581
#  MAE Loss: 5.481663
#
# Best Saved! 5.481662785895517
# Current Best pcorr: 0.47785267048767477
# Current no-progress epoch: 0
#
# Epoch 18
# -------------------------------
# loss: 46.847672  [    0/ 2889]
# loss: 84.827736  [  512/ 2889]
# loss: 57.576736  [ 1024/ 2889]
# loss: 65.235390  [ 1536/ 2889]
# loss: 36.642319  [ 2048/ 2889]
# loss: 40.562256  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 55.519767
#  MAE Loss: 5.317451
#
# Best Saved! 5.317450882861176
# Current Best pcorr: 0.5052709861570759
# Current no-progress epoch: 0
#
# Epoch 19
# -------------------------------
# loss: 25.657112  [    0/ 2889]
# loss: 46.852119  [  512/ 2889]
# loss: 22.753132  [ 1024/ 2889]
# loss: 33.495422  [ 1536/ 2889]
# loss: 76.843430  [ 2048/ 2889]
# loss: 19.442268  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 53.881211
#  MAE Loss: 5.307412
#
# Best Saved! 5.307412132667232
# Current no-progress epoch: 0
#
# Epoch 20
# -------------------------------
# loss: 34.194229  [    0/ 2889]
# loss: 57.678265  [  512/ 2889]
# loss: 27.793934  [ 1024/ 2889]
# loss: 30.879021  [ 1536/ 2889]
# loss: 90.700531  [ 2048/ 2889]
# loss: 56.765022  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 61.128727
#  MAE Loss: 5.594589
#
# Current no-progress epoch: 1
#
# Epoch 21
# -------------------------------
# loss: 27.914154  [    0/ 2889]
# loss: 98.093353  [  512/ 2889]
# loss: 45.894852  [ 1024/ 2889]
# loss: 40.456436  [ 1536/ 2889]
# loss: 74.152534  [ 2048/ 2889]
# loss: 77.448997  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 50.677100
#  MAE Loss: 5.294699
#
# Best Saved! 5.294699487656448
# Current Best pcorr: 0.512351972685503
# Current no-progress epoch: 0
#
# Epoch 22
# -------------------------------
# loss: 41.929710  [    0/ 2889]
# loss: 37.051910  [  512/ 2889]
# loss: 42.132366  [ 1024/ 2889]
# loss: 85.282883  [ 1536/ 2889]
# loss: 34.814514  [ 2048/ 2889]
# loss: 21.352787  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 53.922890
#  MAE Loss: 5.227478
#
# Best Saved! 5.22747774213274
# Current Best pcorr: 0.5282309296285953
# Current no-progress epoch: 0
#
# Epoch 23
# -------------------------------
# loss: 30.257139  [    0/ 2889]
# loss: 64.908630  [  512/ 2889]
# loss: 117.480423  [ 1024/ 2889]
# loss: 45.323647  [ 1536/ 2889]
# loss: 46.587181  [ 2048/ 2889]
# loss: 40.350677  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 51.993390
#  MAE Loss: 5.244796
#
# Current no-progress epoch: 1
#
# Epoch 24
# -------------------------------
# loss: 25.750706  [    0/ 2889]
# loss: 67.787354  [  512/ 2889]
# loss: 20.835125  [ 1024/ 2889]
# loss: 30.902580  [ 1536/ 2889]
# loss: 39.285183  [ 2048/ 2889]
# loss: 56.612732  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 50.241503
#  MAE Loss: 5.099422
#
# Best Saved! 5.099421884411964
# Current Best pcorr: 0.5416036207558561
# Current no-progress epoch: 0
#
# Epoch 25
# -------------------------------
# loss: 67.533447  [    0/ 2889]
# loss: 40.887482  [  512/ 2889]
# loss: 61.568321  [ 1024/ 2889]
# loss: 88.666313  [ 1536/ 2889]
# loss: 72.237061  [ 2048/ 2889]
# loss: 38.659904  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 49.760827
#  MAE Loss: 5.196397
#
# Current no-progress epoch: 1
#
# Epoch 26
# -------------------------------
# loss: 30.225216  [    0/ 2889]
# loss: 55.420853  [  512/ 2889]
# loss: 38.161987  [ 1024/ 2889]
# loss: 28.440937  [ 1536/ 2889]
# loss: 41.007874  [ 2048/ 2889]
# loss: 24.553139  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 49.289607
#  MAE Loss: 5.007008
#
# Best Saved! 5.007008002925884
# Current no-progress epoch: 0
#
# Epoch 27
# -------------------------------
# loss: 40.118553  [    0/ 2889]
# loss: 41.677578  [  512/ 2889]
# loss: 29.526432  [ 1024/ 2889]
# loss: 44.998337  [ 1536/ 2889]
# loss: 50.666855  [ 2048/ 2889]
# loss: 34.866302  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 48.878390
#  MAE Loss: 5.360352
#
# Current no-progress epoch: 1
#
# Epoch 28
# -------------------------------
# loss: 36.704323  [    0/ 2889]
# loss: 39.323959  [  512/ 2889]
# loss: 31.913013  [ 1024/ 2889]
# loss: 71.233139  [ 1536/ 2889]
# loss: 23.035488  [ 2048/ 2889]
# loss: 26.638367  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 48.855291
#  MAE Loss: 5.063777
#
# Current no-progress epoch: 2
#
# Epoch 29
# -------------------------------
# loss: 47.543453  [    0/ 2889]
# loss: 48.419174  [  512/ 2889]
# loss: 33.019920  [ 1024/ 2889]
# loss: 35.270885  [ 1536/ 2889]
# loss: 43.065628  [ 2048/ 2889]
# loss: 38.516937  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 47.149919
#  MAE Loss: 5.105445
#
# Current no-progress epoch: 3
#
# Epoch 30
# -------------------------------
# loss: 17.607136  [    0/ 2889]
# loss: 40.748997  [  512/ 2889]
# loss: 52.490730  [ 1024/ 2889]
# loss: 50.651684  [ 1536/ 2889]
# loss: 55.867554  [ 2048/ 2889]
# loss: 39.875019  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 54.078766
#  MAE Loss: 5.365845
#
# Current no-progress epoch: 4
#
# Epoch 31
# -------------------------------
# loss: 45.530880  [    0/ 2889]
# loss: 31.480274  [  512/ 2889]
# loss: 20.195110  [ 1024/ 2889]
# loss: 41.666531  [ 1536/ 2889]
# loss: 20.312773  [ 2048/ 2889]
# loss: 30.529163  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 48.082910
#  MAE Loss: 5.048615
#
# Current no-progress epoch: 5
#
# Epoch 32
# -------------------------------
# loss: 45.669403  [    0/ 2889]
# loss: 85.021317  [  512/ 2889]
# loss: 193.564514  [ 1024/ 2889]
# loss: 33.146889  [ 1536/ 2889]
# loss: 61.981468  [ 2048/ 2889]
# loss: 46.954380  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 51.437723
#  MAE Loss: 5.182627
#
# Current no-progress epoch: 6
#
# Epoch 33
# -------------------------------
# loss: 34.528587  [    0/ 2889]
# loss: 42.581879  [  512/ 2889]
# loss: 52.055107  [ 1024/ 2889]
# loss: 38.726376  [ 1536/ 2889]
# loss: 37.318977  [ 2048/ 2889]
# loss: 30.259365  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 50.311695
#  MAE Loss: 5.338455
#
# Current no-progress epoch: 7
#
# Epoch 34
# -------------------------------
# loss: 42.820415  [    0/ 2889]
# loss: 20.429642  [  512/ 2889]
# loss: 40.137066  [ 1024/ 2889]
# loss: 54.369801  [ 1536/ 2889]
# loss: 49.056953  [ 2048/ 2889]
# loss: 35.686443  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 48.748392
#  MAE Loss: 5.114283
#
# Current no-progress epoch: 8
#
# Epoch 35
# -------------------------------
# loss: 31.646910  [    0/ 2889]
# loss: 38.697361  [  512/ 2889]
# loss: 18.699471  [ 1024/ 2889]
# loss: 73.818909  [ 1536/ 2889]
# loss: 33.311050  [ 2048/ 2889]
# loss: 27.390709  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 49.681890
#  MAE Loss: 5.186280
#
# Current no-progress epoch: 9
#
# Epoch 36
# -------------------------------
# loss: 27.845501  [    0/ 2889]
# loss: 37.093376  [  512/ 2889]
# loss: 46.787971  [ 1024/ 2889]
# loss: 39.573387  [ 1536/ 2889]
# loss: 31.754318  [ 2048/ 2889]
# loss: 46.041656  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 50.782181
#  MAE Loss: 5.219685
#
# Current no-progress epoch: 10
#
# Epoch 37
# -------------------------------
# loss: 47.811432  [    0/ 2889]
# loss: 53.895889  [  512/ 2889]
# loss: 164.877625  [ 1024/ 2889]
# loss: 30.220736  [ 1536/ 2889]
# loss: 44.589455  [ 2048/ 2889]
# loss: 35.890640  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 52.972452
#  MAE Loss: 5.234609
#
# Current no-progress epoch: 11
#
# Epoch 38
# -------------------------------
# loss: 45.793640  [    0/ 2889]
# loss: 41.687492  [  512/ 2889]
# loss: 75.450951  [ 1024/ 2889]
# loss: 75.659119  [ 1536/ 2889]
# loss: 53.579109  [ 2048/ 2889]
# loss: 25.732273  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 51.876079
#  MAE Loss: 5.208589
#
# Current no-progress epoch: 12
#
# Epoch 39
# -------------------------------
# loss: 61.175980  [    0/ 2889]
# loss: 42.251236  [  512/ 2889]
# loss: 19.834591  [ 1024/ 2889]
# loss: 34.512741  [ 1536/ 2889]
# loss: 34.885471  [ 2048/ 2889]
# loss: 23.086945  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 46.047634
#  MAE Loss: 4.993581
#
# Best Saved! 4.993581094474436
# Current Best pcorr: 0.592006222948761
# Current no-progress epoch: 0
#
# Epoch 40
# -------------------------------
# loss: 35.361614  [    0/ 2889]
# loss: 32.023548  [  512/ 2889]
# loss: 48.168583  [ 1024/ 2889]
# loss: 11.750697  [ 1536/ 2889]
# loss: 31.574499  [ 2048/ 2889]
# loss: 30.253603  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 48.488533
#  MAE Loss: 5.108012
#
# Current no-progress epoch: 1
#
# Epoch 41
# -------------------------------
# loss: 36.822464  [    0/ 2889]
# loss: 34.287498  [  512/ 2889]
# loss: 27.860628  [ 1024/ 2889]
# loss: 67.429443  [ 1536/ 2889]
# loss: 63.638290  [ 2048/ 2889]
# loss: 47.455559  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.775580
#  MAE Loss: 4.878219
#
# Best Saved! 4.878218725091572
# Current no-progress epoch: 0
#
# Epoch 42
# -------------------------------
# loss: 20.776999  [    0/ 2889]
# loss: 39.145573  [  512/ 2889]
# loss: 20.795300  [ 1024/ 2889]
# loss: 17.149586  [ 1536/ 2889]
# loss: 52.398075  [ 2048/ 2889]
# loss: 43.457214  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.737421
#  MAE Loss: 5.031007
#
# Current no-progress epoch: 1
#
# Epoch 43
# -------------------------------
# loss: 15.175287  [    0/ 2889]
# loss: 30.148872  [  512/ 2889]
# loss: 29.664505  [ 1024/ 2889]
# loss: 21.636343  [ 1536/ 2889]
# loss: 57.324173  [ 2048/ 2889]
# loss: 27.297359  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.520397
#  MAE Loss: 4.769378
#
# Best Saved! 4.76937781241824
# Current Best pcorr: 0.6045862615923527
# Current no-progress epoch: 0
#
# Epoch 44
# -------------------------------
# loss: 36.464764  [    0/ 2889]
# loss: 24.395073  [  512/ 2889]
# loss: 20.753334  [ 1024/ 2889]
# loss: 82.141663  [ 1536/ 2889]
# loss: 58.179901  [ 2048/ 2889]
# loss: 75.540855  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.367836
#  MAE Loss: 4.819869
#
# Current no-progress epoch: 1
#
# Epoch 45
# -------------------------------
# loss: 46.159645  [    0/ 2889]
# loss: 39.448658  [  512/ 2889]
# loss: 39.777840  [ 1024/ 2889]
# loss: 89.559875  [ 1536/ 2889]
# loss: 173.917709  [ 2048/ 2889]
# loss: 24.294140  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.628539
#  MAE Loss: 4.855577
#
# Current no-progress epoch: 2
#
# Epoch 46
# -------------------------------
# loss: 34.262161  [    0/ 2889]
# loss: 23.372166  [  512/ 2889]
# loss: 30.877920  [ 1024/ 2889]
# loss: 28.462360  [ 1536/ 2889]
# loss: 39.300476  [ 2048/ 2889]
# loss: 36.662189  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 52.589152
#  MAE Loss: 5.540988
#
# Current no-progress epoch: 3
#
# Epoch 47
# -------------------------------
# loss: 45.776016  [    0/ 2889]
# loss: 71.821877  [  512/ 2889]
# loss: 85.728500  [ 1024/ 2889]
# loss: 29.415747  [ 1536/ 2889]
# loss: 37.030350  [ 2048/ 2889]
# loss: 43.339413  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.200778
#  MAE Loss: 4.785745
#
# Current no-progress epoch: 4
#
# Epoch 48
# -------------------------------
# loss: 38.562782  [    0/ 2889]
# loss: 56.525257  [  512/ 2889]
# loss: 60.840645  [ 1024/ 2889]
# loss: 38.880867  [ 1536/ 2889]
# loss: 38.399475  [ 2048/ 2889]
# loss: 8.285541  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.771392
#  MAE Loss: 4.781910
#
# Current no-progress epoch: 5
#
# Epoch 49
# -------------------------------
# loss: 19.356922  [    0/ 2889]
# loss: 19.131495  [  512/ 2889]
# loss: 68.777740  [ 1024/ 2889]
# loss: 25.095140  [ 1536/ 2889]
# loss: 42.297981  [ 2048/ 2889]
# loss: 22.841784  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 48.234032
#  MAE Loss: 5.170569
#
# Current no-progress epoch: 6
#
# Epoch 50
# -------------------------------
# loss: 56.130054  [    0/ 2889]
# loss: 36.669403  [  512/ 2889]
# loss: 77.393066  [ 1024/ 2889]
# loss: 17.627617  [ 1536/ 2889]
# loss: 35.424408  [ 2048/ 2889]
# loss: 10.233189  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.609738
#  MAE Loss: 4.909036
#
# Current no-progress epoch: 7
#
# Epoch 51
# -------------------------------
# loss: 25.408497  [    0/ 2889]
# loss: 29.007015  [  512/ 2889]
# loss: 41.992355  [ 1024/ 2889]
# loss: 27.546080  [ 1536/ 2889]
# loss: 22.431564  [ 2048/ 2889]
# loss: 30.687870  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 44.310005
#  MAE Loss: 4.857766
#
# Current no-progress epoch: 8
#
# Epoch 52
# -------------------------------
# loss: 26.600796  [    0/ 2889]
# loss: 41.790298  [  512/ 2889]
# loss: 37.348068  [ 1024/ 2889]
# loss: 33.558594  [ 1536/ 2889]
# loss: 31.851330  [ 2048/ 2889]
# loss: 45.382160  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 45.742966
#  MAE Loss: 5.039775
#
# Current no-progress epoch: 9
#
# Epoch 53
# -------------------------------
# loss: 28.846514  [    0/ 2889]
# loss: 61.510014  [  512/ 2889]
# loss: 42.488064  [ 1024/ 2889]
# loss: 31.241808  [ 1536/ 2889]
# loss: 62.918629  [ 2048/ 2889]
# loss: 27.330055  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.982464
#  MAE Loss: 4.711746
#
# Best Saved! 4.711746114808079
# Current Best pcorr: 0.6151560397974731
# Current no-progress epoch: 0
#
# Epoch 54
# -------------------------------
# loss: 24.778595  [    0/ 2889]
# loss: 52.140549  [  512/ 2889]
# loss: 97.991020  [ 1024/ 2889]
# loss: 63.524948  [ 1536/ 2889]
# loss: 69.346161  [ 2048/ 2889]
# loss: 31.630922  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 50.623075
#  MAE Loss: 5.398780
#
# Current no-progress epoch: 1
#
# Epoch 55
# -------------------------------
# loss: 27.201237  [    0/ 2889]
# loss: 24.566696  [  512/ 2889]
# loss: 23.058449  [ 1024/ 2889]
# loss: 22.253834  [ 1536/ 2889]
# loss: 17.783669  [ 2048/ 2889]
# loss: 28.745398  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.650500
#  MAE Loss: 4.757336
#
# Current no-progress epoch: 2
#
# Epoch 56
# -------------------------------
# loss: 22.181311  [    0/ 2889]
# loss: 12.994574  [  512/ 2889]
# loss: 28.772352  [ 1024/ 2889]
# loss: 54.012478  [ 1536/ 2889]
# loss: 22.090668  [ 2048/ 2889]
# loss: 48.472092  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 47.713884
#  MAE Loss: 5.171349
#
# Current no-progress epoch: 3
#
# Epoch 57
# -------------------------------
# loss: 41.241314  [    0/ 2889]
# loss: 40.819893  [  512/ 2889]
# loss: 25.228100  [ 1024/ 2889]
# loss: 16.346098  [ 1536/ 2889]
# loss: 43.263550  [ 2048/ 2889]
# loss: 33.180489  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.505344
#  MAE Loss: 4.674998
#
# Best Saved! 4.674998411136996
# Current Best pcorr: 0.6263984389124688
# Current no-progress epoch: 0
#
# Epoch 58
# -------------------------------
# loss: 34.048729  [    0/ 2889]
# loss: 41.484722  [  512/ 2889]
# loss: 41.561153  [ 1024/ 2889]
# loss: 21.412615  [ 1536/ 2889]
# loss: 47.897400  [ 2048/ 2889]
# loss: 41.970444  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 44.609647
#  MAE Loss: 4.926647
#
# Current no-progress epoch: 1
#
# Epoch 59
# -------------------------------
# loss: 23.954369  [    0/ 2889]
# loss: 62.400925  [  512/ 2889]
# loss: 43.248150  [ 1024/ 2889]
# loss: 46.303284  [ 1536/ 2889]
# loss: 68.891556  [ 2048/ 2889]
# loss: 30.367588  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.903690
#  MAE Loss: 4.899212
#
# Current no-progress epoch: 2
#
# Epoch 60
# -------------------------------
# loss: 34.146942  [    0/ 2889]
# loss: 37.548630  [  512/ 2889]
# loss: 22.264931  [ 1024/ 2889]
# loss: 36.414753  [ 1536/ 2889]
# loss: 26.699251  [ 2048/ 2889]
# loss: 26.272568  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.183280
#  MAE Loss: 4.810981
#
# Current no-progress epoch: 3
#
# Epoch 61
# -------------------------------
# loss: 77.061218  [    0/ 2889]
# loss: 36.167179  [  512/ 2889]
# loss: 14.853935  [ 1024/ 2889]
# loss: 36.234161  [ 1536/ 2889]
# loss: 37.779099  [ 2048/ 2889]
# loss: 24.008595  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.721107
#  MAE Loss: 4.808366
#
# Current no-progress epoch: 4
#
# Epoch 62
# -------------------------------
# loss: 24.689114  [    0/ 2889]
# loss: 32.344097  [  512/ 2889]
# loss: 20.095123  [ 1024/ 2889]
# loss: 29.609959  [ 1536/ 2889]
# loss: 29.712151  [ 2048/ 2889]
# loss: 41.234707  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.215436
#  MAE Loss: 4.669806
#
# Best Saved! 4.669806043678355
# Current Best pcorr: 0.6411205196620567
# Current no-progress epoch: 0
#
# Epoch 63
# -------------------------------
# loss: 32.700851  [    0/ 2889]
# loss: 35.234348  [  512/ 2889]
# loss: 27.244972  [ 1024/ 2889]
# loss: 35.121822  [ 1536/ 2889]
# loss: 32.964920  [ 2048/ 2889]
# loss: 42.857605  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.369759
#  MAE Loss: 4.660297
#
# Best Saved! 4.660296710480782
# Current Best pcorr: 0.6466115578676731
# Current no-progress epoch: 0
#
# Epoch 64
# -------------------------------
# loss: 19.507099  [    0/ 2889]
# loss: 20.990578  [  512/ 2889]
# loss: 50.728996  [ 1024/ 2889]
# loss: 16.222025  [ 1536/ 2889]
# loss: 47.339615  [ 2048/ 2889]
# loss: 13.214211  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.738804
#  MAE Loss: 4.697948
#
# Current no-progress epoch: 1
#
# Epoch 65
# -------------------------------
# loss: 20.361940  [    0/ 2889]
# loss: 35.533581  [  512/ 2889]
# loss: 32.527821  [ 1024/ 2889]
# loss: 62.495007  [ 1536/ 2889]
# loss: 16.405525  [ 2048/ 2889]
# loss: 17.500528  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 45.316425
#  MAE Loss: 5.087196
#
# Current no-progress epoch: 2
#
# Epoch 66
# -------------------------------
# loss: 24.298069  [    0/ 2889]
# loss: 23.092022  [  512/ 2889]
# loss: 37.762268  [ 1024/ 2889]
# loss: 24.123215  [ 1536/ 2889]
# loss: 19.687168  [ 2048/ 2889]
# loss: 33.991051  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.987809
#  MAE Loss: 4.724049
#
# Current no-progress epoch: 3
#
# Epoch 67
# -------------------------------
# loss: 41.592819  [    0/ 2889]
# loss: 25.160154  [  512/ 2889]
# loss: 24.735079  [ 1024/ 2889]
# loss: 17.288231  [ 1536/ 2889]
# loss: 24.510115  [ 2048/ 2889]
# loss: 36.781780  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.543874
#  MAE Loss: 4.672945
#
# Current no-progress epoch: 4
#
# Epoch 68
# -------------------------------
# loss: 23.628637  [    0/ 2889]
# loss: 38.058571  [  512/ 2889]
# loss: 32.635445  [ 1024/ 2889]
# loss: 30.704107  [ 1536/ 2889]
# loss: 21.230062  [ 2048/ 2889]
# loss: 39.274147  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.360154
#  MAE Loss: 4.673812
#
# Current no-progress epoch: 5
#
# Epoch 69
# -------------------------------
# loss: 36.960434  [    0/ 2889]
# loss: 15.425411  [  512/ 2889]
# loss: 42.394909  [ 1024/ 2889]
# loss: 28.255087  [ 1536/ 2889]
# loss: 36.659737  [ 2048/ 2889]
# loss: 39.597893  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.760789
#  MAE Loss: 4.889433
#
# Current no-progress epoch: 6
#
# Epoch 70
# -------------------------------
# loss: 40.292480  [    0/ 2889]
# loss: 19.440132  [  512/ 2889]
# loss: 69.241043  [ 1024/ 2889]
# loss: 80.372345  [ 1536/ 2889]
# loss: 32.466949  [ 2048/ 2889]
# loss: 45.525909  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.684459
#  MAE Loss: 4.668324
#
# Current no-progress epoch: 7
#
# Epoch 71
# -------------------------------
# loss: 28.622118  [    0/ 2889]
# loss: 41.615726  [  512/ 2889]
# loss: 28.264948  [ 1024/ 2889]
# loss: 21.872967  [ 1536/ 2889]
# loss: 38.317635  [ 2048/ 2889]
# loss: 26.598091  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.343640
#  MAE Loss: 4.938034
#
# Current no-progress epoch: 8
#
# Epoch 72
# -------------------------------
# loss: 24.333952  [    0/ 2889]
# loss: 42.029465  [  512/ 2889]
# loss: 57.629784  [ 1024/ 2889]
# loss: 42.335052  [ 1536/ 2889]
# loss: 27.974976  [ 2048/ 2889]
# loss: 27.532227  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.469166
#  MAE Loss: 4.619466
#
# Best Saved! 4.619466413218656
# Current no-progress epoch: 0
#
# Epoch 73
# -------------------------------
# loss: 46.816658  [    0/ 2889]
# loss: 21.011753  [  512/ 2889]
# loss: 39.964066  [ 1024/ 2889]
# loss: 34.580929  [ 1536/ 2889]
# loss: 16.262270  [ 2048/ 2889]
# loss: 31.546368  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 46.444020
#  MAE Loss: 5.093011
#
# Current no-progress epoch: 1
#
# Epoch 74
# -------------------------------
# loss: 54.877464  [    0/ 2889]
# loss: 50.778252  [  512/ 2889]
# loss: 32.265537  [ 1024/ 2889]
# loss: 25.205353  [ 1536/ 2889]
# loss: 29.354321  [ 2048/ 2889]
# loss: 29.559952  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.867159
#  MAE Loss: 4.808732
#
# Current no-progress epoch: 2
#
# Epoch 75
# -------------------------------
# loss: 48.982178  [    0/ 2889]
# loss: 27.753998  [  512/ 2889]
# loss: 22.713257  [ 1024/ 2889]
# loss: 34.444073  [ 1536/ 2889]
# loss: 32.931301  [ 2048/ 2889]
# loss: 24.126034  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.276154
#  MAE Loss: 4.631000
#
# Current no-progress epoch: 3
#
# Epoch 76
# -------------------------------
# loss: 11.463474  [    0/ 2889]
# loss: 46.675179  [  512/ 2889]
# loss: 90.053650  [ 1024/ 2889]
# loss: 51.578423  [ 1536/ 2889]
# loss: 14.060378  [ 2048/ 2889]
# loss: 17.933678  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.059462
#  MAE Loss: 4.579046
#
# Best Saved! 4.57904603548139
# Current no-progress epoch: 0
#
# Epoch 77
# -------------------------------
# loss: 108.231476  [    0/ 2889]
# loss: 48.475639  [  512/ 2889]
# loss: 25.975092  [ 1024/ 2889]
# loss: 16.783140  [ 1536/ 2889]
# loss: 9.311779  [ 2048/ 2889]
# loss: 50.862923  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.734390
#  MAE Loss: 4.986965
#
# Current no-progress epoch: 1
#
# Epoch 78
# -------------------------------
# loss: 16.409628  [    0/ 2889]
# loss: 32.459480  [  512/ 2889]
# loss: 47.905373  [ 1024/ 2889]
# loss: 42.870834  [ 1536/ 2889]
# loss: 43.347931  [ 2048/ 2889]
# loss: 21.737963  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.763069
#  MAE Loss: 4.717390
#
# Current no-progress epoch: 2
#
# Epoch 79
# -------------------------------
# loss: 9.955196  [    0/ 2889]
# loss: 27.940651  [  512/ 2889]
# loss: 19.458614  [ 1024/ 2889]
# loss: 43.275475  [ 1536/ 2889]
# loss: 41.575943  [ 2048/ 2889]
# loss: 35.514576  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.395861
#  MAE Loss: 4.794376
#
# Current no-progress epoch: 3
#
# Epoch 80
# -------------------------------
# loss: 27.838287  [    0/ 2889]
# loss: 26.110687  [  512/ 2889]
# loss: 15.545389  [ 1024/ 2889]
# loss: 25.451557  [ 1536/ 2889]
# loss: 25.931076  [ 2048/ 2889]
# loss: 21.691023  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.890181
#  MAE Loss: 4.923108
#
# Current no-progress epoch: 4
#
# Epoch 81
# -------------------------------
# loss: 30.659275  [    0/ 2889]
# loss: 15.990019  [  512/ 2889]
# loss: 17.758959  [ 1024/ 2889]
# loss: 65.326599  [ 1536/ 2889]
# loss: 34.445927  [ 2048/ 2889]
# loss: 14.651919  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.079224
#  MAE Loss: 4.571636
#
# Best Saved! 4.571635938507746
# Current no-progress epoch: 0
#
# Epoch 82
# -------------------------------
# loss: 28.313438  [    0/ 2889]
# loss: 16.535536  [  512/ 2889]
# loss: 23.424866  [ 1024/ 2889]
# loss: 44.473812  [ 1536/ 2889]
# loss: 73.294220  [ 2048/ 2889]
# loss: 49.224678  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.202544
#  MAE Loss: 4.754297
#
# Current no-progress epoch: 1
#
# Epoch 83
# -------------------------------
# loss: 15.952447  [    0/ 2889]
# loss: 65.106590  [  512/ 2889]
# loss: 38.072659  [ 1024/ 2889]
# loss: 34.690048  [ 1536/ 2889]
# loss: 20.562225  [ 2048/ 2889]
# loss: 35.480293  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.884631
#  MAE Loss: 4.774227
#
# Current no-progress epoch: 2
#
# Epoch 84
# -------------------------------
# loss: 18.822119  [    0/ 2889]
# loss: 34.118565  [  512/ 2889]
# loss: 48.114246  [ 1024/ 2889]
# loss: 20.482521  [ 1536/ 2889]
# loss: 37.360748  [ 2048/ 2889]
# loss: 24.250343  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.807351
#  MAE Loss: 4.720929
#
# Current no-progress epoch: 3
#
# Epoch 85
# -------------------------------
# loss: 9.069424  [    0/ 2889]
# loss: 16.078682  [  512/ 2889]
# loss: 26.692120  [ 1024/ 2889]
# loss: 20.574148  [ 1536/ 2889]
# loss: 30.477013  [ 2048/ 2889]
# loss: 10.679498  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.441057
#  MAE Loss: 4.729380
#
# Current no-progress epoch: 4
#
# Epoch 86
# -------------------------------
# loss: 34.620090  [    0/ 2889]
# loss: 24.572477  [  512/ 2889]
# loss: 19.113556  [ 1024/ 2889]
# loss: 27.223434  [ 1536/ 2889]
# loss: 26.017946  [ 2048/ 2889]
# loss: 16.286472  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.164476
#  MAE Loss: 4.692444
#
# Current no-progress epoch: 5
#
# Epoch 87
# -------------------------------
# loss: 48.022259  [    0/ 2889]
# loss: 15.615460  [  512/ 2889]
# loss: 21.070118  [ 1024/ 2889]
# loss: 28.507967  [ 1536/ 2889]
# loss: 32.347443  [ 2048/ 2889]
# loss: 28.771145  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.525406
#  MAE Loss: 4.685988
#
# Current no-progress epoch: 6
#
# Epoch 88
# -------------------------------
# loss: 10.302342  [    0/ 2889]
# loss: 26.932102  [  512/ 2889]
# loss: 31.202568  [ 1024/ 2889]
# loss: 33.798992  [ 1536/ 2889]
# loss: 68.845001  [ 2048/ 2889]
# loss: 27.621052  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.037086
#  MAE Loss: 4.707286
#
# Current no-progress epoch: 7
#
# Epoch 89
# -------------------------------
# loss: 34.742786  [    0/ 2889]
# loss: 49.661587  [  512/ 2889]
# loss: 23.460197  [ 1024/ 2889]
# loss: 20.866428  [ 1536/ 2889]
# loss: 22.040545  [ 2048/ 2889]
# loss: 13.449709  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.871617
#  MAE Loss: 4.551782
#
# Best Saved! 4.551782055435893
# Current no-progress epoch: 0
#
# Epoch 90
# -------------------------------
# loss: 42.237511  [    0/ 2889]
# loss: 89.508507  [  512/ 2889]
# loss: 26.356798  [ 1024/ 2889]
# loss: 18.432095  [ 1536/ 2889]
# loss: 52.812263  [ 2048/ 2889]
# loss: 21.022301  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.007998
#  MAE Loss: 4.558145
#
# Current no-progress epoch: 1
#
# Epoch 91
# -------------------------------
# loss: 27.763351  [    0/ 2889]
# loss: 10.463071  [  512/ 2889]
# loss: 41.595905  [ 1024/ 2889]
# loss: 30.107603  [ 1536/ 2889]
# loss: 12.987375  [ 2048/ 2889]
# loss: 25.711033  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.846051
#  MAE Loss: 4.651120
#
# Current no-progress epoch: 2
#
# Epoch 92
# -------------------------------
# loss: 62.868568  [    0/ 2889]
# loss: 44.548977  [  512/ 2889]
# loss: 27.535349  [ 1024/ 2889]
# loss: 30.808960  [ 1536/ 2889]
# loss: 23.315125  [ 2048/ 2889]
# loss: 35.942375  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.791733
#  MAE Loss: 4.869652
#
# Current no-progress epoch: 3
#
# Epoch 93
# -------------------------------
# loss: 30.708847  [    0/ 2889]
# loss: 33.752590  [  512/ 2889]
# loss: 18.139854  [ 1024/ 2889]
# loss: 23.292116  [ 1536/ 2889]
# loss: 15.624263  [ 2048/ 2889]
# loss: 21.620161  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.174607
#  MAE Loss: 4.873875
#
# Current no-progress epoch: 4
#
# Epoch 94
# -------------------------------
# loss: 28.650415  [    0/ 2889]
# loss: 25.798382  [  512/ 2889]
# loss: 29.810610  [ 1024/ 2889]
# loss: 41.793289  [ 1536/ 2889]
# loss: 22.403336  [ 2048/ 2889]
# loss: 21.364325  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.761849
#  MAE Loss: 4.671249
#
# Current no-progress epoch: 5
#
# Epoch 95
# -------------------------------
# loss: 43.661274  [    0/ 2889]
# loss: 14.943791  [  512/ 2889]
# loss: 15.007227  [ 1024/ 2889]
# loss: 28.122559  [ 1536/ 2889]
# loss: 57.535416  [ 2048/ 2889]
# loss: 32.859356  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.808612
#  MAE Loss: 4.781855
#
# Current no-progress epoch: 6
#
# Epoch 96
# -------------------------------
# loss: 18.901070  [    0/ 2889]
# loss: 37.486671  [  512/ 2889]
# loss: 37.188381  [ 1024/ 2889]
# loss: 31.563496  [ 1536/ 2889]
# loss: 22.340071  [ 2048/ 2889]
# loss: 26.718086  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.933466
#  MAE Loss: 4.698418
#
# Current no-progress epoch: 7
#
# Epoch 97
# -------------------------------
# loss: 30.797905  [    0/ 2889]
# loss: 25.724590  [  512/ 2889]
# loss: 21.027397  [ 1024/ 2889]
# loss: 16.327642  [ 1536/ 2889]
# loss: 19.524609  [ 2048/ 2889]
# loss: 26.002422  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.801817
#  MAE Loss: 4.756554
#
# Current no-progress epoch: 8
#
# Epoch 98
# -------------------------------
# loss: 31.160101  [    0/ 2889]
# loss: 22.401514  [  512/ 2889]
# loss: 27.677839  [ 1024/ 2889]
# loss: 12.047780  [ 1536/ 2889]
# loss: 19.309858  [ 2048/ 2889]
# loss: 16.320269  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.853652
#  MAE Loss: 4.609080
#
# Current no-progress epoch: 9
#
# Epoch 99
# -------------------------------
# loss: 37.743206  [    0/ 2889]
# loss: 7.920616  [  512/ 2889]
# loss: 15.133642  [ 1024/ 2889]
# loss: 18.777424  [ 1536/ 2889]
# loss: 23.665497  [ 2048/ 2889]
# loss: 24.425037  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.940371
#  MAE Loss: 4.514231
#
# Best Saved! 4.514231060895593
# Current no-progress epoch: 0
#
# Epoch 100
# -------------------------------
# loss: 25.881269  [    0/ 2889]
# loss: 29.553886  [  512/ 2889]
# loss: 41.995670  [ 1024/ 2889]
# loss: 33.907784  [ 1536/ 2889]
# loss: 35.894653  [ 2048/ 2889]
# loss: 40.039646  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.703028
#  MAE Loss: 4.647653
#
# Current no-progress epoch: 1
#
# Epoch 101
# -------------------------------
# loss: 16.411030  [    0/ 2889]
# loss: 22.797199  [  512/ 2889]
# loss: 49.506733  [ 1024/ 2889]
# loss: 28.468557  [ 1536/ 2889]
# loss: 17.528185  [ 2048/ 2889]
# loss: 22.468700  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.128463
#  MAE Loss: 4.689205
#
# Current no-progress epoch: 2
#
# Epoch 102
# -------------------------------
# loss: 16.745890  [    0/ 2889]
# loss: 32.657658  [  512/ 2889]
# loss: 38.278343  [ 1024/ 2889]
# loss: 28.643154  [ 1536/ 2889]
# loss: 46.287830  [ 2048/ 2889]
# loss: 31.064285  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.026893
#  MAE Loss: 4.631673
#
# Current no-progress epoch: 3
#
# Epoch 103
# -------------------------------
# loss: 16.684139  [    0/ 2889]
# loss: 25.542099  [  512/ 2889]
# loss: 25.519348  [ 1024/ 2889]
# loss: 19.100782  [ 1536/ 2889]
# loss: 32.548187  [ 2048/ 2889]
# loss: 46.866280  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.214907
#  MAE Loss: 4.678088
#
# Current no-progress epoch: 4
#
# Epoch 104
# -------------------------------
# loss: 25.157528  [    0/ 2889]
# loss: 27.320465  [  512/ 2889]
# loss: 25.246630  [ 1024/ 2889]
# loss: 24.267443  [ 1536/ 2889]
# loss: 35.920105  [ 2048/ 2889]
# loss: 27.756538  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.335071
#  MAE Loss: 4.718448
#
# Current no-progress epoch: 5
#
# Epoch 105
# -------------------------------
# loss: 26.538635  [    0/ 2889]
# loss: 29.194748  [  512/ 2889]
# loss: 66.602081  [ 1024/ 2889]
# loss: 18.566908  [ 1536/ 2889]
# loss: 17.895576  [ 2048/ 2889]
# loss: 18.436563  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.005298
#  MAE Loss: 4.648604
#
# Current no-progress epoch: 6
#
# Epoch 106
# -------------------------------
# loss: 36.421467  [    0/ 2889]
# loss: 16.547878  [  512/ 2889]
# loss: 27.830246  [ 1024/ 2889]
# loss: 23.485165  [ 1536/ 2889]
# loss: 38.667656  [ 2048/ 2889]
# loss: 24.038353  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 44.559291
#  MAE Loss: 4.982305
#
# Current no-progress epoch: 7
#
# Epoch 107
# -------------------------------
# loss: 17.250475  [    0/ 2889]
# loss: 32.879616  [  512/ 2889]
# loss: 29.973284  [ 1024/ 2889]
# loss: 19.681145  [ 1536/ 2889]
# loss: 37.756409  [ 2048/ 2889]
# loss: 20.937351  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.838040
#  MAE Loss: 4.871006
#
# Current no-progress epoch: 8
#
# Epoch 108
# -------------------------------
# loss: 52.429276  [    0/ 2889]
# loss: 24.268555  [  512/ 2889]
# loss: 14.338626  [ 1024/ 2889]
# loss: 47.193535  [ 1536/ 2889]
# loss: 30.966530  [ 2048/ 2889]
# loss: 43.972645  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.082849
#  MAE Loss: 4.743695
#
# Current no-progress epoch: 9
#
# Epoch 109
# -------------------------------
# loss: 126.590408  [    0/ 2889]
# loss: 13.587340  [  512/ 2889]
# loss: 33.480911  [ 1024/ 2889]
# loss: 25.987434  [ 1536/ 2889]
# loss: 16.368799  [ 2048/ 2889]
# loss: 19.338280  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.880219
#  MAE Loss: 4.701037
#
# Current no-progress epoch: 10
#
# Epoch 110
# -------------------------------
# loss: 11.752989  [    0/ 2889]
# loss: 32.557819  [  512/ 2889]
# loss: 15.175800  [ 1024/ 2889]
# loss: 34.998142  [ 1536/ 2889]
# loss: 17.465149  [ 2048/ 2889]
# loss: 35.084171  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.478972
#  MAE Loss: 4.508694
#
# Best Saved! 4.508694128826771
# Current no-progress epoch: 0
#
# Epoch 111
# -------------------------------
# loss: 30.791897  [    0/ 2889]
# loss: 58.184280  [  512/ 2889]
# loss: 17.788795  [ 1024/ 2889]
# loss: 32.872807  [ 1536/ 2889]
# loss: 31.613409  [ 2048/ 2889]
# loss: 38.423706  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.818349
#  MAE Loss: 4.723423
#
# Current no-progress epoch: 1
#
# Epoch 112
# -------------------------------
# loss: 43.880840  [    0/ 2889]
# loss: 55.262962  [  512/ 2889]
# loss: 18.328892  [ 1024/ 2889]
# loss: 44.350212  [ 1536/ 2889]
# loss: 22.412552  [ 2048/ 2889]
# loss: 30.150845  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.027389
#  MAE Loss: 4.521560
#
# Current no-progress epoch: 2
#
# Epoch 113
# -------------------------------
# loss: 10.674648  [    0/ 2889]
# loss: 17.636858  [  512/ 2889]
# loss: 13.524849  [ 1024/ 2889]
# loss: 10.519184  [ 1536/ 2889]
# loss: 11.604250  [ 2048/ 2889]
# loss: 19.792057  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.101914
#  MAE Loss: 4.737342
#
# Current no-progress epoch: 3
#
# Epoch 114
# -------------------------------
# loss: 43.089539  [    0/ 2889]
# loss: 45.995014  [  512/ 2889]
# loss: 26.459129  [ 1024/ 2889]
# loss: 20.859161  [ 1536/ 2889]
# loss: 26.412085  [ 2048/ 2889]
# loss: 32.557449  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.402529
#  MAE Loss: 4.570482
#
# Current no-progress epoch: 4
#
# Epoch 115
# -------------------------------
# loss: 19.233479  [    0/ 2889]
# loss: 16.690517  [  512/ 2889]
# loss: 29.047798  [ 1024/ 2889]
# loss: 11.695375  [ 1536/ 2889]
# loss: 29.113926  [ 2048/ 2889]
# loss: 26.775158  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.165910
#  MAE Loss: 4.585125
#
# Current no-progress epoch: 5
#
# Epoch 116
# -------------------------------
# loss: 49.408943  [    0/ 2889]
# loss: 37.512188  [  512/ 2889]
# loss: 25.857910  [ 1024/ 2889]
# loss: 36.727081  [ 1536/ 2889]
# loss: 50.066391  [ 2048/ 2889]
# loss: 16.874052  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.553755
#  MAE Loss: 4.707241
#
# Current no-progress epoch: 6
#
# Epoch 117
# -------------------------------
# loss: 26.092972  [    0/ 2889]
# loss: 24.742849  [  512/ 2889]
# loss: 37.449497  [ 1024/ 2889]
# loss: 27.166693  [ 1536/ 2889]
# loss: 55.763023  [ 2048/ 2889]
# loss: 22.418358  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.843198
#  MAE Loss: 4.572338
#
# Current no-progress epoch: 7
#
# Epoch 118
# -------------------------------
# loss: 28.092224  [    0/ 2889]
# loss: 37.066788  [  512/ 2889]
# loss: 33.144451  [ 1024/ 2889]
# loss: 17.256813  [ 1536/ 2889]
# loss: 23.129366  [ 2048/ 2889]
# loss: 10.327425  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.935159
#  MAE Loss: 4.605158
#
# Current no-progress epoch: 8
#
# Epoch 119
# -------------------------------
# loss: 8.146334  [    0/ 2889]
# loss: 43.168133  [  512/ 2889]
# loss: 17.240538  [ 1024/ 2889]
# loss: 20.205976  [ 1536/ 2889]
# loss: 14.741386  [ 2048/ 2889]
# loss: 41.662235  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.365960
#  MAE Loss: 4.514241
#
# Current no-progress epoch: 9
#
# Epoch 120
# -------------------------------
# loss: 14.449059  [    0/ 2889]
# loss: 24.592484  [  512/ 2889]
# loss: 19.102818  [ 1024/ 2889]
# loss: 38.986069  [ 1536/ 2889]
# loss: 24.943707  [ 2048/ 2889]
# loss: 15.812387  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.654958
#  MAE Loss: 4.542259
#
# Current no-progress epoch: 10
#
# Epoch 121
# -------------------------------
# loss: 30.474979  [    0/ 2889]
# loss: 53.406242  [  512/ 2889]
# loss: 15.826696  [ 1024/ 2889]
# loss: 16.576866  [ 1536/ 2889]
# loss: 27.043886  [ 2048/ 2889]
# loss: 18.102837  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.466900
#  MAE Loss: 4.543507
#
# Current no-progress epoch: 11
#
# Epoch 122
# -------------------------------
# loss: 10.790245  [    0/ 2889]
# loss: 12.176156  [  512/ 2889]
# loss: 16.753410  [ 1024/ 2889]
# loss: 19.247257  [ 1536/ 2889]
# loss: 37.047920  [ 2048/ 2889]
# loss: 14.746739  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.960994
#  MAE Loss: 4.513827
#
# Current no-progress epoch: 12
#
# Epoch 123
# -------------------------------
# loss: 11.955528  [    0/ 2889]
# loss: 17.451048  [  512/ 2889]
# loss: 23.948978  [ 1024/ 2889]
# loss: 26.271076  [ 1536/ 2889]
# loss: 41.092468  [ 2048/ 2889]
# loss: 15.077240  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.488126
#  MAE Loss: 4.586669
#
# Current no-progress epoch: 13
#
# Epoch 124
# -------------------------------
# loss: 14.115607  [    0/ 2889]
# loss: 40.573856  [  512/ 2889]
# loss: 11.600170  [ 1024/ 2889]
# loss: 18.995485  [ 1536/ 2889]
# loss: 22.136608  [ 2048/ 2889]
# loss: 23.338140  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.620011
#  MAE Loss: 4.670451
#
# Current no-progress epoch: 14
#
# Epoch 125
# -------------------------------
# loss: 14.001226  [    0/ 2889]
# loss: 64.859543  [  512/ 2889]
# loss: 19.721138  [ 1024/ 2889]
# loss: 18.269524  [ 1536/ 2889]
# loss: 12.968664  [ 2048/ 2889]
# loss: 11.797841  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.160018
#  MAE Loss: 4.685401
#
# Current no-progress epoch: 15
#
# Epoch 126
# -------------------------------
# loss: 39.578339  [    0/ 2889]
# loss: 17.350395  [  512/ 2889]
# loss: 14.914791  [ 1024/ 2889]
# loss: 17.926981  [ 1536/ 2889]
# loss: 22.106647  [ 2048/ 2889]
# loss: 30.079838  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.769705
#  MAE Loss: 4.607961
#
# Current no-progress epoch: 16
#
# Epoch 127
# -------------------------------
# loss: 27.050686  [    0/ 2889]
# loss: 20.617363  [  512/ 2889]
# loss: 19.617140  [ 1024/ 2889]
# loss: 10.026792  [ 1536/ 2889]
# loss: 30.063826  [ 2048/ 2889]
# loss: 47.700439  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.821126
#  MAE Loss: 4.509016
#
# Current no-progress epoch: 17
#
# Epoch 128
# -------------------------------
# loss: 31.105709  [    0/ 2889]
# loss: 22.411491  [  512/ 2889]
# loss: 18.930824  [ 1024/ 2889]
# loss: 19.757601  [ 1536/ 2889]
# loss: 10.264723  [ 2048/ 2889]
# loss: 15.456617  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.558813
#  MAE Loss: 4.477730
#
# Best Saved! 4.477730213296005
# Current no-progress epoch: 0
#
# Epoch 129
# -------------------------------
# loss: 36.005280  [    0/ 2889]
# loss: 13.083459  [  512/ 2889]
# loss: 9.262463  [ 1024/ 2889]
# loss: 56.104027  [ 1536/ 2889]
# loss: 19.809179  [ 2048/ 2889]
# loss: 24.193958  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.584590
#  MAE Loss: 4.510094
#
# Current no-progress epoch: 1
#
# Epoch 130
# -------------------------------
# loss: 42.491058  [    0/ 2889]
# loss: 35.441994  [  512/ 2889]
# loss: 28.783279  [ 1024/ 2889]
# loss: 27.775541  [ 1536/ 2889]
# loss: 38.223545  [ 2048/ 2889]
# loss: 41.085209  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.339935
#  MAE Loss: 4.443054
#
# Best Saved! 4.443053569377769
# Current no-progress epoch: 0
#
# Epoch 131
# -------------------------------
# loss: 9.357340  [    0/ 2889]
# loss: 27.185038  [  512/ 2889]
# loss: 13.714003  [ 1024/ 2889]
# loss: 29.247709  [ 1536/ 2889]
# loss: 18.194298  [ 2048/ 2889]
# loss: 14.914292  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.619473
#  MAE Loss: 4.497590
#
# Current no-progress epoch: 1
#
# Epoch 132
# -------------------------------
# loss: 20.495152  [    0/ 2889]
# loss: 17.973854  [  512/ 2889]
# loss: 24.398029  [ 1024/ 2889]
# loss: 14.957157  [ 1536/ 2889]
# loss: 40.392578  [ 2048/ 2889]
# loss: 62.090103  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.443234
#  MAE Loss: 4.374274
#
# Best Saved! 4.374274179571514
# Current no-progress epoch: 0
#
# Epoch 133
# -------------------------------
# loss: 34.127472  [    0/ 2889]
# loss: 12.370792  [  512/ 2889]
# loss: 49.343090  [ 1024/ 2889]
# loss: 39.008320  [ 1536/ 2889]
# loss: 18.123220  [ 2048/ 2889]
# loss: 9.356343  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 35.092642
#  MAE Loss: 4.299546
#
# Best Saved! 4.299545531703676
# Current no-progress epoch: 0
#
# Epoch 134
# -------------------------------
# loss: 38.911770  [    0/ 2889]
# loss: 29.184961  [  512/ 2889]
# loss: 49.403229  [ 1024/ 2889]
# loss: 21.286575  [ 1536/ 2889]
# loss: 50.234291  [ 2048/ 2889]
# loss: 10.492485  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.460684
#  MAE Loss: 4.439912
#
# Current no-progress epoch: 1
#
# Epoch 135
# -------------------------------
# loss: 22.341152  [    0/ 2889]
# loss: 10.096075  [  512/ 2889]
# loss: 15.048011  [ 1024/ 2889]
# loss: 16.421598  [ 1536/ 2889]
# loss: 16.796070  [ 2048/ 2889]
# loss: 10.973070  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 35.965839
#  MAE Loss: 4.356744
#
# Current no-progress epoch: 2
#
# Epoch 136
# -------------------------------
# loss: 19.090942  [    0/ 2889]
# loss: 23.923328  [  512/ 2889]
# loss: 27.270561  [ 1024/ 2889]
# loss: 27.008699  [ 1536/ 2889]
# loss: 15.233756  [ 2048/ 2889]
# loss: 18.757824  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.818251
#  MAE Loss: 4.629655
#
# Current no-progress epoch: 3
#
# Epoch 137
# -------------------------------
# loss: 24.263294  [    0/ 2889]
# loss: 27.914200  [  512/ 2889]
# loss: 28.061562  [ 1024/ 2889]
# loss: 21.154861  [ 1536/ 2889]
# loss: 4.288853  [ 2048/ 2889]
# loss: 20.810108  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.112841
#  MAE Loss: 4.867235
#
# Current no-progress epoch: 4
#
# Epoch 138
# -------------------------------
# loss: 29.693268  [    0/ 2889]
# loss: 8.955252  [  512/ 2889]
# loss: 10.057133  [ 1024/ 2889]
# loss: 23.133945  [ 1536/ 2889]
# loss: 16.644737  [ 2048/ 2889]
# loss: 19.436707  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.423291
#  MAE Loss: 4.427872
#
# Current no-progress epoch: 5
#
# Epoch 139
# -------------------------------
# loss: 26.371487  [    0/ 2889]
# loss: 45.858978  [  512/ 2889]
# loss: 19.195095  [ 1024/ 2889]
# loss: 40.844933  [ 1536/ 2889]
# loss: 11.367304  [ 2048/ 2889]
# loss: 32.467140  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.920451
#  MAE Loss: 4.347002
#
# Current no-progress epoch: 6
#
# Epoch 140
# -------------------------------
# loss: 65.251801  [    0/ 2889]
# loss: 21.328255  [  512/ 2889]
# loss: 21.208916  [ 1024/ 2889]
# loss: 21.381601  [ 1536/ 2889]
# loss: 35.399765  [ 2048/ 2889]
# loss: 15.285563  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.802195
#  MAE Loss: 4.553101
#
# Current no-progress epoch: 7
#
# Epoch 141
# -------------------------------
# loss: 19.343225  [    0/ 2889]
# loss: 24.367413  [  512/ 2889]
# loss: 29.262486  [ 1024/ 2889]
# loss: 13.267174  [ 1536/ 2889]
# loss: 20.607315  [ 2048/ 2889]
# loss: 27.498718  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 44.876109
#  MAE Loss: 5.091678
#
# Current no-progress epoch: 8
#
# Epoch 142
# -------------------------------
# ...
#  MAE Loss: 5.405583
#
# Current no-progress epoch: 1
#
# Epoch 11
# -------------------------------
# loss: 28.628986  [    0/ 2889]
# loss: 24.907341  [  512/ 2889]
# loss: 31.299698  [ 1024/ 2889]
# loss: 34.413528  [ 1536/ 2889]
# loss: 40.422890  [ 2048/ 2889]
# loss: 93.757599  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 43.440481
#  MAE Loss: 5.043038
#
# Best Saved! 5.043037723529376
# Current Best pcorr: 0.5370596506207411
# Current no-progress epoch: 0
#
# Epoch 12
# -------------------------------
# loss: 40.983780  [    0/ 2889]
# loss: 34.084450  [  512/ 2889]
# loss: 75.178947  [ 1024/ 2889]
# loss: 55.501297  [ 1536/ 2889]
# loss: 66.012016  [ 2048/ 2889]
# loss: 55.013443  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.247877
#  MAE Loss: 5.002999
#
# Best Saved! 5.0029990888458915
# Current Best pcorr: 0.5555467596312388
# Current no-progress epoch: 0
#
# Epoch 13
# -------------------------------
# loss: 25.796951  [    0/ 2889]
# loss: 52.515770  [  512/ 2889]
# loss: 40.560951  [ 1024/ 2889]
# loss: 91.805962  [ 1536/ 2889]
# loss: 63.278973  [ 2048/ 2889]
# loss: 47.965755  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 44.810601
#  MAE Loss: 5.287839
#
# Current no-progress epoch: 1
#
# Epoch 14
# -------------------------------
# loss: 50.817188  [    0/ 2889]
# loss: 56.357498  [  512/ 2889]
# loss: 46.892235  [ 1024/ 2889]
# loss: 42.201420  [ 1536/ 2889]
# loss: 38.709911  [ 2048/ 2889]
# loss: 64.319733  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.252656
#  MAE Loss: 4.900244
#
# Best Saved! 4.900244442473319
# Current Best pcorr: 0.5730576843539994
# Current no-progress epoch: 0
#
# Epoch 15
# -------------------------------
# loss: 43.054409  [    0/ 2889]
# loss: 30.425177  [  512/ 2889]
# loss: 24.228996  [ 1024/ 2889]
# loss: 66.862869  [ 1536/ 2889]
# loss: 26.332642  [ 2048/ 2889]
# loss: 76.844299  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.168875
#  MAE Loss: 5.106869
#
# Current no-progress epoch: 1
#
# Epoch 16
# -------------------------------
# loss: 38.263134  [    0/ 2889]
# loss: 48.483105  [  512/ 2889]
# loss: 78.161789  [ 1024/ 2889]
# loss: 41.477646  [ 1536/ 2889]
# loss: 60.781593  [ 2048/ 2889]
# loss: 31.901356  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.058717
#  MAE Loss: 5.041221
#
# Current no-progress epoch: 2
#
# Epoch 17
# -------------------------------
# loss: 18.750006  [    0/ 2889]
# loss: 43.529953  [  512/ 2889]
# loss: 32.193794  [ 1024/ 2889]
# loss: 33.934025  [ 1536/ 2889]
# loss: 31.825050  [ 2048/ 2889]
# loss: 33.418560  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.382757
#  MAE Loss: 4.886172
#
# Best Saved! 4.886172006434741
# Current Best pcorr: 0.5740199136825214
# Current no-progress epoch: 0
#
# Epoch 18
# -------------------------------
# loss: 13.665414  [    0/ 2889]
# loss: 26.235901  [  512/ 2889]
# loss: 53.146034  [ 1024/ 2889]
# loss: 75.456184  [ 1536/ 2889]
# loss: 56.787128  [ 2048/ 2889]
# loss: 56.206879  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 49.585902
#  MAE Loss: 5.587473
#
# Current no-progress epoch: 1
#
# Epoch 19
# -------------------------------
# loss: 55.511681  [    0/ 2889]
# loss: 67.229568  [  512/ 2889]
# loss: 36.747082  [ 1024/ 2889]
# loss: 47.570671  [ 1536/ 2889]
# loss: 81.875305  [ 2048/ 2889]
# loss: 58.655613  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.795295
#  MAE Loss: 5.020507
#
# Current no-progress epoch: 2
#
# Epoch 20
# -------------------------------
# loss: 32.737110  [    0/ 2889]
# loss: 31.500923  [  512/ 2889]
# loss: 45.051350  [ 1024/ 2889]
# loss: 39.634232  [ 1536/ 2889]
# loss: 57.592789  [ 2048/ 2889]
# loss: 40.585899  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.477834
#  MAE Loss: 4.735134
#
# Best Saved! 4.735134148523444
# Current Best pcorr: 0.6020224727298669
# Current no-progress epoch: 0
#
# Epoch 21
# -------------------------------
# loss: 32.616707  [    0/ 2889]
# loss: 38.371552  [  512/ 2889]
# loss: 60.442566  [ 1024/ 2889]
# loss: 45.759689  [ 1536/ 2889]
# loss: 32.456154  [ 2048/ 2889]
# loss: 46.011574  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.271808
#  MAE Loss: 4.885156
#
# Current no-progress epoch: 1
#
# Epoch 22
# -------------------------------
# loss: 45.686726  [    0/ 2889]
# loss: 27.280823  [  512/ 2889]
# loss: 45.507298  [ 1024/ 2889]
# loss: 42.693874  [ 1536/ 2889]
# loss: 69.539017  [ 2048/ 2889]
# loss: 47.215500  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.083058
#  MAE Loss: 4.723466
#
# Best Saved! 4.723466397817261
# Current Best pcorr: 0.6119749570759851
# Current no-progress epoch: 0
#
# Epoch 23
# -------------------------------
# loss: 57.135254  [    0/ 2889]
# loss: 69.554207  [  512/ 2889]
# loss: 32.613811  [ 1024/ 2889]
# loss: 44.852417  [ 1536/ 2889]
# loss: 59.009575  [ 2048/ 2889]
# loss: 40.924377  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.907781
#  MAE Loss: 4.804108
#
# Current no-progress epoch: 1
#
# Epoch 24
# -------------------------------
# loss: 60.881893  [    0/ 2889]
# loss: 25.595463  [  512/ 2889]
# loss: 163.012009  [ 1024/ 2889]
# loss: 40.045425  [ 1536/ 2889]
# loss: 16.645683  [ 2048/ 2889]
# loss: 86.634956  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 41.340520
#  MAE Loss: 5.037555
#
# Current no-progress epoch: 2
#
# Epoch 25
# -------------------------------
# loss: 69.717628  [    0/ 2889]
# loss: 23.575432  [  512/ 2889]
# loss: 31.064814  [ 1024/ 2889]
# loss: 58.899803  [ 1536/ 2889]
# loss: 42.322922  [ 2048/ 2889]
# loss: 84.266235  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.571480
#  MAE Loss: 4.886812
#
# Current no-progress epoch: 3
#
# Epoch 26
# -------------------------------
# loss: 48.686291  [    0/ 2889]
# loss: 47.233383  [  512/ 2889]
# loss: 52.101620  [ 1024/ 2889]
# loss: 32.048992  [ 1536/ 2889]
# loss: 24.951235  [ 2048/ 2889]
# loss: 86.687065  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.232122
#  MAE Loss: 4.849130
#
# Current no-progress epoch: 4
#
# Epoch 27
# -------------------------------
# loss: 31.266270  [    0/ 2889]
# loss: 25.525295  [  512/ 2889]
# loss: 35.662231  [ 1024/ 2889]
# loss: 32.789433  [ 1536/ 2889]
# loss: 74.688736  [ 2048/ 2889]
# loss: 26.542187  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.806465
#  MAE Loss: 4.693874
#
# Best Saved! 4.693874382898444
# Current Best pcorr: 0.6376398132136883
# Current no-progress epoch: 0
#
# Epoch 28
# -------------------------------
# loss: 81.977783  [    0/ 2889]
# loss: 30.483643  [  512/ 2889]
# loss: 47.147793  [ 1024/ 2889]
# loss: 22.977316  [ 1536/ 2889]
# loss: 42.936935  [ 2048/ 2889]
# loss: 48.336906  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.275375
#  MAE Loss: 4.743517
#
# Current no-progress epoch: 1
#
# Epoch 29
# -------------------------------
# loss: 13.727905  [    0/ 2889]
# loss: 56.303085  [  512/ 2889]
# loss: 31.724504  [ 1024/ 2889]
# loss: 52.692757  [ 1536/ 2889]
# loss: 81.746429  [ 2048/ 2889]
# loss: 37.491817  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.515275
#  MAE Loss: 4.692846
#
# Best Saved! 4.692846114018995
# Current no-progress epoch: 0
#
# Epoch 30
# -------------------------------
# loss: 20.739407  [    0/ 2889]
# loss: 17.252350  [  512/ 2889]
# loss: 51.057808  [ 1024/ 2889]
# loss: 33.742718  [ 1536/ 2889]
# loss: 22.504517  [ 2048/ 2889]
# loss: 29.620743  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.610735
#  MAE Loss: 4.654671
#
# Best Saved! 4.654671315463532
# Current no-progress epoch: 0
#
# Epoch 31
# -------------------------------
# loss: 15.408693  [    0/ 2889]
# loss: 41.867958  [  512/ 2889]
# loss: 53.648884  [ 1024/ 2889]
# loss: 22.789303  [ 1536/ 2889]
# loss: 62.505302  [ 2048/ 2889]
# loss: 50.166935  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.084725
#  MAE Loss: 4.522428
#
# Best Saved! 4.522428102582414
# Current no-progress epoch: 0
#
# Epoch 32
# -------------------------------
# loss: 44.416622  [    0/ 2889]
# loss: 48.187916  [  512/ 2889]
# loss: 22.537804  [ 1024/ 2889]
# loss: 52.830593  [ 1536/ 2889]
# loss: 37.153999  [ 2048/ 2889]
# loss: 36.284821  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.726925
#  MAE Loss: 4.463319
#
# Best Saved! 4.463318679191613
# Current Best pcorr: 0.6386006905526441
# Current no-progress epoch: 0
#
# Epoch 33
# -------------------------------
# loss: 47.095833  [    0/ 2889]
# loss: 41.006477  [  512/ 2889]
# loss: 32.357151  [ 1024/ 2889]
# loss: 34.864754  [ 1536/ 2889]
# loss: 32.423027  [ 2048/ 2889]
# loss: 24.910110  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.180324
#  MAE Loss: 4.656443
#
# Current no-progress epoch: 1
#
# Epoch 34
# -------------------------------
# loss: 65.355698  [    0/ 2889]
# loss: 77.485443  [  512/ 2889]
# loss: 35.673576  [ 1024/ 2889]
# loss: 28.741470  [ 1536/ 2889]
# loss: 24.997417  [ 2048/ 2889]
# loss: 21.415289  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 40.785889
#  MAE Loss: 4.899625
#
# Current no-progress epoch: 2
#
# Epoch 35
# -------------------------------
# loss: 37.867687  [    0/ 2889]
# loss: 21.688751  [  512/ 2889]
# loss: 43.004524  [ 1024/ 2889]
# loss: 44.977619  [ 1536/ 2889]
# loss: 44.436493  [ 2048/ 2889]
# loss: 56.090645  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 35.353560
#  MAE Loss: 4.303142
#
# Best Saved! 4.303142090081426
# Current no-progress epoch: 0
#
# Epoch 36
# -------------------------------
# loss: 32.152939  [    0/ 2889]
# loss: 45.492428  [  512/ 2889]
# loss: 73.821945  [ 1024/ 2889]
# loss: 35.148010  [ 1536/ 2889]
# loss: 27.041172  [ 2048/ 2889]
# loss: 18.733479  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 34.762179
#  MAE Loss: 4.417116
#
# Current no-progress epoch: 1
#
# Epoch 37
# -------------------------------
# loss: 39.194626  [    0/ 2889]
# loss: 33.204910  [  512/ 2889]
# loss: 33.206383  [ 1024/ 2889]
# loss: 41.349510  [ 1536/ 2889]
# loss: 21.867584  [ 2048/ 2889]
# loss: 31.107784  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 34.831404
#  MAE Loss: 4.295009
#
# Best Saved! 4.295008775229766
# Current no-progress epoch: 0
#
# Epoch 38
# -------------------------------
# loss: 43.943535  [    0/ 2889]
# loss: 24.888519  [  512/ 2889]
# loss: 23.582577  [ 1024/ 2889]
# loss: 44.100914  [ 1536/ 2889]
# loss: 35.152325  [ 2048/ 2889]
# loss: 58.657455  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.427956
#  MAE Loss: 4.797782
#
# Current no-progress epoch: 1
#
# Epoch 39
# -------------------------------
# loss: 32.284870  [    0/ 2889]
# loss: 39.059006  [  512/ 2889]
# loss: 30.434103  [ 1024/ 2889]
# loss: 64.336700  [ 1536/ 2889]
# loss: 13.040369  [ 2048/ 2889]
# loss: 54.040161  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.886636
#  MAE Loss: 4.665649
#
# Current no-progress epoch: 2
#
# Epoch 40
# -------------------------------
# loss: 46.102066  [    0/ 2889]
# loss: 41.898586  [  512/ 2889]
# loss: 27.212782  [ 1024/ 2889]
# loss: 21.506733  [ 1536/ 2889]
# loss: 31.866856  [ 2048/ 2889]
# loss: 30.540962  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 35.853313
#  MAE Loss: 4.414017
#
# Current no-progress epoch: 3
#
# Epoch 41
# -------------------------------
# loss: 31.974445  [    0/ 2889]
# loss: 13.681833  [  512/ 2889]
# loss: 44.482292  [ 1024/ 2889]
# loss: 81.274605  [ 1536/ 2889]
# loss: 57.350708  [ 2048/ 2889]
# loss: 77.729744  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.573372
#  MAE Loss: 4.623684
#
# Current no-progress epoch: 4
#
# Epoch 42
# -------------------------------
# loss: 20.118532  [    0/ 2889]
# loss: 54.399536  [  512/ 2889]
# loss: 47.406403  [ 1024/ 2889]
# loss: 27.351307  [ 1536/ 2889]
# loss: 44.790138  [ 2048/ 2889]
# loss: 50.874664  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.030083
#  MAE Loss: 4.741915
#
# Current no-progress epoch: 5
#
# Epoch 43
# -------------------------------
# loss: 23.261929  [    0/ 2889]
# loss: 13.436382  [  512/ 2889]
# loss: 88.562057  [ 1024/ 2889]
# loss: 53.493790  [ 1536/ 2889]
# loss: 54.909389  [ 2048/ 2889]
# loss: 99.488647  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 35.417796
#  MAE Loss: 4.419271
#
# Current no-progress epoch: 6
#
# Epoch 44
# -------------------------------
# loss: 37.933891  [    0/ 2889]
# loss: 39.485558  [  512/ 2889]
# loss: 36.219376  [ 1024/ 2889]
# loss: 25.285349  [ 1536/ 2889]
# loss: 25.321402  [ 2048/ 2889]
# loss: 25.261667  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.711735
#  MAE Loss: 4.582508
#
# Current no-progress epoch: 7
#
# Epoch 45
# -------------------------------
# loss: 43.144821  [    0/ 2889]
# loss: 24.280964  [  512/ 2889]
# loss: 22.663532  [ 1024/ 2889]
# loss: 39.788815  [ 1536/ 2889]
# loss: 47.709969  [ 2048/ 2889]
# loss: 16.147789  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.812247
#  MAE Loss: 4.821996
#
# Current no-progress epoch: 8
#
# Epoch 46
# -------------------------------
# loss: 44.363056  [    0/ 2889]
# loss: 38.525536  [  512/ 2889]
# loss: 33.858101  [ 1024/ 2889]
# loss: 30.829308  [ 1536/ 2889]
# loss: 18.804527  [ 2048/ 2889]
# loss: 35.286972  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 38.759852
#  MAE Loss: 4.659849
#
# Current no-progress epoch: 9
#
# Epoch 47
# -------------------------------
# loss: 36.432877  [    0/ 2889]
# loss: 36.811214  [  512/ 2889]
# loss: 26.730221  [ 1024/ 2889]
# loss: 28.087349  [ 1536/ 2889]
# loss: 57.302303  [ 2048/ 2889]
# loss: 51.227005  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 35.500966
#  MAE Loss: 4.464803
#
# Current no-progress epoch: 10
#
# Epoch 48
# -------------------------------
# loss: 72.701485  [    0/ 2889]
# loss: 29.002411  [  512/ 2889]
# loss: 19.627960  [ 1024/ 2889]
# loss: 70.803345  [ 1536/ 2889]
# loss: 17.613628  [ 2048/ 2889]
# loss: 50.684731  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 42.381704
#  MAE Loss: 4.966772
#
# Current no-progress epoch: 11
#
# Epoch 49
# -------------------------------
# loss: 32.447517  [    0/ 2889]
# loss: 38.967815  [  512/ 2889]
# loss: 28.668129  [ 1024/ 2889]
# loss: 35.203976  [ 1536/ 2889]
# loss: 22.511431  [ 2048/ 2889]
# loss: 17.084095  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.162873
#  MAE Loss: 4.518970
#
# Current no-progress epoch: 12
#
# Epoch 50
# -------------------------------
# loss: 75.513596  [    0/ 2889]
# loss: 20.973497  [  512/ 2889]
# loss: 10.246693  [ 1024/ 2889]
# loss: 28.256256  [ 1536/ 2889]
# loss: 17.734026  [ 2048/ 2889]
# loss: 26.274364  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.030046
#  MAE Loss: 4.477019
#
# Current no-progress epoch: 13
#
# Epoch 51
# -------------------------------
# loss: 30.475912  [    0/ 2889]
# loss: 29.449364  [  512/ 2889]
# loss: 33.999756  [ 1024/ 2889]
# loss: 40.085995  [ 1536/ 2889]
# loss: 19.799295  [ 2048/ 2889]
# loss: 31.487253  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 37.906516
#  MAE Loss: 4.622365
#
# Current no-progress epoch: 14
#
# Epoch 52
# -------------------------------
# loss: 35.407593  [    0/ 2889]
# loss: 59.544991  [  512/ 2889]
# loss: 35.708858  [ 1024/ 2889]
# loss: 55.605904  [ 1536/ 2889]
# loss: 24.000542  [ 2048/ 2889]
# loss: 47.947624  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 35.992452
#  MAE Loss: 4.352435
#
# Current no-progress epoch: 15
#
# Epoch 53
# -------------------------------
# loss: 69.906174  [    0/ 2889]
# loss: 39.510719  [  512/ 2889]
# loss: 48.137733  [ 1024/ 2889]
# loss: 97.381393  [ 1536/ 2889]
# loss: 34.010540  [ 2048/ 2889]
# loss: 34.748199  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.030398
#  MAE Loss: 4.470960
#
# Current no-progress epoch: 16
#
# Epoch 54
# -------------------------------
# loss: 19.210192  [    0/ 2889]
# loss: 25.400599  [  512/ 2889]
# loss: 33.029358  [ 1024/ 2889]
# loss: 59.653759  [ 1536/ 2889]
# loss: 19.324589  [ 2048/ 2889]
# loss: 34.679543  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.605393
#  MAE Loss: 4.547983
#
# Current no-progress epoch: 17
#
# Epoch 55
# -------------------------------
# loss: 19.971170  [    0/ 2889]
# loss: 18.830883  [  512/ 2889]
# loss: 27.975830  [ 1024/ 2889]
# loss: 18.555027  [ 1536/ 2889]
# loss: 47.020206  [ 2048/ 2889]
# loss: 23.579487  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 35.162207
#  MAE Loss: 4.354450
#
# Current no-progress epoch: 18
#
# Epoch 56
# -------------------------------
# loss: 34.136269  [    0/ 2889]
# loss: 28.183332  [  512/ 2889]
# loss: 41.785744  [ 1024/ 2889]
# loss: 29.058640  [ 1536/ 2889]
# loss: 34.385445  [ 2048/ 2889]
# loss: 58.108692  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 36.343115
#  MAE Loss: 4.503147
#
# Current no-progress epoch: 19
#
# Epoch 57
# -------------------------------
# loss: 27.334003  [    0/ 2889]
# loss: 63.021900  [  512/ 2889]
# loss: 51.043846  [ 1024/ 2889]
# loss: 27.553822  [ 1536/ 2889]
# loss: 43.963974  [ 2048/ 2889]
# loss: 17.957100  [ 2560/ 2889]
# Validation Error:
#  MSE Loss: 39.070141
#  MAE Loss: 4.721469
#
# Early Stopped!
# Skipping lr of 2.782559402207126e-05
# Skipping lr of 3.5938136638046256e-05
# Skipping lr of 4.641588833612782e-05
# Skipping lr of 5.994842503189409e-05
# Skipping lr of 7.742636826811278e-05
# Skipping lr of 0.0001
